# %%
import pandas as pd

# %%
NF1_data = pd.read_csv("./YAGO/NF_data/result_NF1.csv")
NF2_data = pd.read_csv("./YAGO/NF_data/result_NF2.csv")
NF3_data = pd.read_csv("./YAGO/NF_data/result_NF3.csv")
NF4_data = pd.read_csv("./YAGO/NF_data/result_NF4.csv")

# %%
NF1_data["Probability"].plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
NF2_data["Probability"].plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
NF3_data["Probability"].plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
NF4_data["Probability"].plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
len(NF1_data)
# Out:
# 16002

# %%
len(NF2_data)
# Out:
# 117600

# %%
len(NF3_data)
# Out:
# 96012

# %%
len(NF4_data)
# Out:
# 96012
